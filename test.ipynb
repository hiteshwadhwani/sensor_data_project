# %%
print("hello world")
# Out:
# hello world

# %%
import pymongo
import pandas as pd
import certifi
import json

# Create connection
client = pymongo.MongoClient(
    "mongodb+srv://hiteshwadhwani1403:indore11@ineuron.xskip.mongodb.net/?retryWrites=true&w=majority",
    tlsCAFile=certifi.where())
print(client)

DATA_FILE_PATH = '/config/workspace/aps_failure_training_set1.csv'
DATABASE_NAME = 'aps'
COLLECTION_NAME = 'sesor'

db = client[DATABASE_NAME] #database
col = db[COLLECTION_NAME]  #collection
# Out:
# MongoClient(host=['ineuron-shard-00-01.xskip.mongodb.net:27017', 'ineuron-shard-00-00.xskip.mongodb.net:27017', 'ineuron-shard-00-02.xskip.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-v2iltd-shard-0', tls=True, tlscafile='/config/.local/lib/python3.8/site-packages/certifi/cacert.pem')

# %%
df = pd.read_csv(DATA_FILE_PATH)

# %%
df.head()
# Out:
#   class  aa_000 ab_000 ac_000 ad_000 ae_000 af_000 ag_000  ag_001   ag_002  \
# 0   pos  153204      0    182     na      0      0      0       0        0
# 1   pos  453236     na   2926     na      0      0      0       0      222
# 2   pos   72504     na   1594   1052      0      0      0     244   178226
# 3   pos  762958     na     na     na     na     na    776  281128  2186308
# 4   pos  695994     na     na     na     na     na      0       0        0
#
#    ...   ee_002   ee_003   ee_004   ee_005   ee_006  ee_007  ee_008 ee_009  \
# 0  ...   129862    26872    34044    22472    34362       0       0      0
# 1  ...  7908038  3026002  5025350  2025766  1160638  533834  493800   6914
# 2  ...  1432098   372252   527514   358274   332818  284178    3742      0
# 3  ...       na       na       na       na       na      na      na     na
# 4  ...  1397742   495544   361646    28610     5130     212       0      0
#
#   ef_000 eg_000
# 0      0      0
# 1      0      0
# ...

# %%
list(json.loads(df.iloc[:100,:].T.to_json()).values())
# Out:
# [{'class': 'pos',
#   'aa_000': 153204,
#   'ab_000': '0',
#   'ac_000': '182',
#   'ad_000': 'na',
#   'ae_000': '0',
#   'af_000': '0',
#   'ag_000': '0',
#   'ag_001': '0',
#   'ag_002': '0',
#   'ag_003': '11804',
#   'ag_004': '684444',
#   'ag_005': '326536',
#   'ag_006': '31586',
#   'ag_007': '0',
#   'ag_008': '0',
#   'ag_009': '0',
#   'ah_000': '2658638',
#   'ai_000': '14346',
#   'aj_000': '0',
#   'ak_000': '0',
#   'al_000': '29384',
#   'am_0': '46356',
#   'an_000': '5566182',
#   'ao_000': '4426834',
#   'ap_000': '1571480',
#   'aq_000': '1120644',
#   'ar_000': '2',
#   'as_000': '0',
#   'at_000': '0',
#   'au_000': '0',
#   'av_000': '1368',
#   'ax_000': '862',
#   'ay_000': '0',
#   'ay_001': '0',
#   'ay_002': '0',
#   'ay_003': '0',
#   'ay_004': '0',
#   'ay_005': '0',
#   'ay_006': '0',
#   'ay_007': '94188',
#   'ay_008': '960182',
#   'ay_009': '0',
#   'az_000': '250',
#   'az_001': '16',
#   'az_002': '32',
#   'az_003': '146',
#   'az_004': '126',
# ...
